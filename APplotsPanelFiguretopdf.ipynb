# %%
import neurphys.read_pv as rpv
import matplotlib.pyplot as plt
import neurphys.utilities as util

# %matplotlib inline

# %%
#opens the folder containing the voltage recording files 
data = rpv.import_folder(r'/Users/ezt309/Documents/2p/electrophys/test recording/test_recording_IC0')

# %%
#generates a plot of the selected output over time. Figure size can be changed according to preferences
f, ax1 = plt.subplots(1, figsize=(12, 5))
ax1.plot(vm.time, vm.primary)

#Activate the following line to save a .pdf file of the figure. Specify save path and desired name.
plt.savefig(r'/Users/ezt309/Documents/2p/electrophys/test recording/test_recording_IC0againmore2.pdf')

# %%
#generates a plot of the selected output over time, for the selected time interval. Figure size can be changed according to preferences

f, ax1 = plt.subplots(1, figsize=(12, 6))
ax1.plot(vm.time, vm.primary)
ax1.set_xlim(5,10)

#Activate the following line to save a .pdf file of the figure. Specify save path and desired name.
plt.savefig(r'/Users/ezt309/Documents/2p/electrophys/test recording/test_recording_IC0again5-10s_more.pdf')
