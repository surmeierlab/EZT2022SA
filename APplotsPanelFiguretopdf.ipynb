# %%
import neurphys.read_pv as rpv
import matplotlib.pyplot as plt
import neurphys.utilities as util

# %matplotlib inline

# %%
data = rpv.import_folder(r'/Users/ezt309/Documents/2p/electrophys/just_ephys_2020-21/MCUko/3_5_21/VoltageRecording-03052021-1510_#2070_S2C1-007')

# %%
vm = data['voltage recording']
ls = data['linescan']

# %%
f, ax1 = plt.subplots(1, figsize=(12, 4))
ax1.plot(vm.time, vm.primary)

#ax2 = ax1.twinx()
#ax2.plot(ls['Prof 1 Time'], util.simple_smoothing(ls['Prof 1'].values, 10), c='r')
#ax2.set_ylim(1500, 3000)


#plt.savefig(r'/Users/ezt309/Documents/2p/electrophys/ephys_PercevalHR/2018/4_16_18/VoltageRecording-04162018-1350_percevalhr_s1c1-007.pdf')

# %%
#plt.plot(ls['Prof 1 Time'], ls['Prof 1'])

# %%
f, ax1 = plt.subplots(1, figsize=(12, 6))
ax1.plot(vm.time, vm.primary)

#ax2 = ax1.twinx()
#ax2.plot(ls['Prof 1 Time'], util.simple_smoothing(ls['Prof 1'].values, 10), c='r')
#ax2.set_ylim(2200, 2600)
ax1.set_xlim(285,300)

plt.savefig(r'/Users/ezt309/Documents/2p/electrophys/just_ephys_2020-21/MCUko/3_5_21/VoltageRecording-03052021-1510_#2070_S2C1-006_45-60s.pdf')
